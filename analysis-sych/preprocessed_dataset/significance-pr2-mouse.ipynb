# %%
# Standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import IntProgress
from IPython.display import display

# Append base directory
import os,sys,inspect
rootname = "pub-2020-exploratory-analysis"
# thispath = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
thispath = os.getcwd()
rootpath = os.path.join(thispath[:thispath.index(rootname)], rootname)
sys.path.append(rootpath)
print("Appended root directory", rootpath)

from mesostat.metric.metric import MetricCalculator
from mesostat.utils.qt_helper import gui_fname, gui_fnames, gui_fpath
from mesostat.utils.hdf5_io import DataStorage
from mesostat.utils.pandas_helper import pd_query
from mesostat.visualization.mpl_matrix import plot_df_2D_outer_product

from lib.sych.data_fc_db_raw import DataFCDatabase
import lib.analysis.triplet_analysis.mousewise as mousewise
import lib.analysis.triplet_analysis.calc_reader_mousewise as calc_reader

# %load_ext autoreload
# %autoreload 2
# Out:
# Appended root directory /home/alyosha/work/git/pub-2020-exploratory-analysis

# %%
# tmp_path = root_path_data if 'root_path_data' in locals() else "./"
params = {}
# params['root_path_data'] = './'
params['root_path_data'] = '/media/alyosha/Data/TE_data/yarodata/sych_preprocessed'
# params['root_path_data'] = '/media/aleksejs/DataHDD/work/data/yaro/neuronal-raw-pooled'
# params['root_path_data'] = gui_fpath('h5path', './')

# %%
dataDB = DataFCDatabase(params)
# Out:
# Searching for data files
# Extracting trial type names
# Extracting data types
# Reading area color map

# %%
h5outname = 'sych_result_higher_order_df.h5'

# %%
mc = MetricCalculator(serial=False, verbose=False, nCore=4)
# Out:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-2:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/py3ml/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/py3ml/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/py3ml/lib/python3.8/site-packages/multiprocess/process.py", line 315, in _bootstrap
#     self.run()
#   File "/opt/anaconda3/envs/py3ml/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/opt/anaconda3/envs/py3ml/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# ...

# %% [markdown]
# ## All - Distribution - Nosession

# %%
prefixPath = '/media/alyosha/Data/TE_data/calculations/pr2/yaro/'

pwdH5data = prefixPath + 'pr2_sych_multimouse_data.h5'
pwdH5rand = prefixPath + 'pr2_sych_multimouse_rand.h5'

# %%
dfSummary = calc_reader.summary_df(pwdH5data)
dfSummaryDataSizes = calc_reader.summary_update_data_sizes(dfSummary, dataDB)

# %%
dfSummaryRand = calc_reader.summary_df(pwdH5rand)

# %%
pwdAdversarial = '/media/alyosha/Data/TE_data/pr2_rand_dist.h5'

# %%
dictAdversarial = calc_reader.read_adversarial_distr_file(pwdAdversarial)

# %%
rezTestShuffle = mousewise.plot_violin_test(pwdH5data, pwdH5rand, dfSummary, dfSummaryRand, thrBig=0.01)

# %%
rezTestAdversarial = mousewise.plot_violin_test_adversarial(pwdH5data, dictAdversarial, dfSummaryDataSizes, thrBig=0.01)
# Out:
# unique ['PR2_mvg_4_PRE_bn_session_None_expert', 'PR2', 'mvg_4', 'PRE', 'bn_session', 'None', 'expert', 3278]
# unique ['PR2_mvg_7_PRE_bn_session_None_expert', 'PR2', 'mvg_7', 'PRE', 'bn_session', 'None', 'expert', 1525]
# unique ['PR2_mvg_8_PRE_bn_session_None_expert', 'PR2', 'mvg_8', 'PRE', 'bn_session', 'None', 'expert', 2767]
# unique ['PR2_mvg_9_PRE_bn_session_None_expert', 'PR2', 'mvg_9', 'PRE', 'bn_session', 'None', 'expert', 2891]
# red ['PR2_mvg_4_PRE_bn_session_None_expert', 'PR2', 'mvg_4', 'PRE', 'bn_session', 'None', 'expert', 3278]
# red ['PR2_mvg_7_PRE_bn_session_None_expert', 'PR2', 'mvg_7', 'PRE', 'bn_session', 'None', 'expert', 1525]
# red ['PR2_mvg_8_PRE_bn_session_None_expert', 'PR2', 'mvg_8', 'PRE', 'bn_session', 'None', 'expert', 2767]
# red ['PR2_mvg_9_PRE_bn_session_None_expert', 'PR2', 'mvg_9', 'PRE', 'bn_session', 'None', 'expert', 2891]
# unique ['PR2_mvg_4_PRE_bn_session_iGO_expert', 'PR2', 'mvg_4', 'PRE', 'bn_session', 'iGO', 'expert', 1412]
# ...

# %%
rezTestAdversarial
# Out:
#                                       key metric mousename intervName  \
# 28   PR2_mvg_4_PRE_bn_session_None_expert    PR2     mvg_4        PRE
# 34   PR2_mvg_7_PRE_bn_session_None_expert    PR2     mvg_7        PRE
# 113  PR2_mvg_8_PRE_bn_session_None_expert    PR2     mvg_8        PRE
# 10   PR2_mvg_9_PRE_bn_session_None_expert    PR2     mvg_9        PRE
# 28   PR2_mvg_4_PRE_bn_session_None_expert    PR2     mvg_4        PRE
# ..                                    ...    ...       ...        ...
# 2      PR2_mvg_9_TEX_bn_trial_iNOGO_naive    PR2     mvg_9        TEX
# 0      PR2_mvg_4_TEX_bn_trial_iNOGO_naive    PR2     mvg_4        TEX
# 85     PR2_mvg_7_TEX_bn_trial_iNOGO_naive    PR2     mvg_7        TEX
# 37     PR2_mvg_8_TEX_bn_trial_iNOGO_naive    PR2     mvg_8        TEX
# 2      PR2_mvg_9_TEX_bn_trial_iNOGO_naive    PR2     mvg_9        TEX
#
#        datatype trialType performance nData  -log10(pval)    atom   fracBig  \
# ...

# %%
def inf_update(df, key, val):
    df.loc[df[key] == np.inf, key] = val
    df.loc[df[key] == -np.inf, key] = val
    return df

rezTestShuffle = inf_update(rezTestShuffle, '-log10(pval)', 1000)
rezTestAdversarial = inf_update(rezTestAdversarial, '-log10(pval)', 1000)

# Plot significance
print('Shuffle-Sign')
fig, ax = plt.subplots(ncols=3, figsize=(24,4), tight_layout=True)
for iPid, pidType in enumerate(['red', 'unique', 'syn']):
    dfQuery = pd_query(rezTestShuffle, {'atom': pidType})
    plot_df_2D_outer_product(ax[iPid], dfQuery, ['datatype', 'mousename'], ['trialType', 'intervName', 'performance'],
                             '-log10(pval)', vmin=0, vmax=10, orderDict={'intervName': ['PRE', 'TEX', 'REW']})
    
plt.savefig('pid_tex_neglogpval_shuffle_outer2d.svg')
plt.show()


# Plot significance
print('Adv-Sign')
fig, ax = plt.subplots(ncols=3, figsize=(24,4), tight_layout=True)
for iPid, pidType in enumerate(['red', 'unique', 'syn']):
    dfQuery = pd_query(rezTestAdversarial, {'atom': pidType})
    plot_df_2D_outer_product(ax[iPid], dfQuery, ['datatype', 'mousename'], ['trialType', 'intervName', 'performance'],
                             '-log10(pval)', vmin=0, vmax=10, orderDict={'intervName': ['PRE', 'TEX', 'REW']})
    
plt.savefig('pid_tex_neglogpval_adversarial_outer2d.svg')
plt.show()
# Out:
# Shuffle-Sign
# Adv-Sign
# /opt/anaconda3/envs/py3ml/lib/python3.8/site-packages/seaborn/matrix.py:301: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))
# /opt/anaconda3/envs/py3ml/lib/python3.8/site-packages/seaborn/matrix.py:301: UserWarning: Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#   ax.set(xlim=(0, self.data.shape[1]), ylim=(0, self.data.shape[0]))

# %%
print('Shuffle-Sign')
fig, ax = plt.subplots(ncols=3, figsize=(24,4), tight_layout=True)
for iPid, pidType in enumerate(['red', 'unique', 'syn']):
    dfQuery = pd_query(rezTestShuffle, {'atom': pidType})
    plot_df_2D_outer_product(ax[iPid], dfQuery, ['datatype', 'mousename'], ['trialType', 'intervName', 'performance'],
                             'fracSign', vmin=0, orderDict={'intervName': ['PRE', 'TEX', 'REW']})
    
plt.savefig('pid_tex_significant_shuffle_outer2d.svg')
plt.show()


print('Adv-Sign')
fig, ax = plt.subplots(ncols=3, figsize=(24,4), tight_layout=True)
for iPid, pidType in enumerate(['red', 'unique']):
    dfQuery = pd_query(rezTestAdversarial, {'atom': pidType})
    plot_df_2D_outer_product(ax[iPid], dfQuery, ['datatype', 'mousename'], ['trialType', 'intervName', 'performance'],
                             'fracSign', vmin=0, orderDict={'intervName': ['PRE', 'TEX', 'REW']})
    
plt.savefig('pid_tex_significant_adversarial_outer2d.svg')
plt.show()

print('Shuffle-Big')
fig, ax = plt.subplots(ncols=3, figsize=(24,4), tight_layout=True)
for iPid, pidType in enumerate(['red', 'unique', 'syn']):
    dfQuery = pd_query(rezTestShuffle, {'atom': pidType})
    plot_df_2D_outer_product(ax[iPid], dfQuery, ['datatype', 'mousename'], ['trialType', 'intervName', 'performance'],
                             'fracBig', vmin=0, orderDict={'intervName': ['PRE', 'TEX', 'REW']})
    
plt.savefig('pid_tex_big_outer2d.svg')
plt.show()
# Out:
# Shuffle-Sign
# Adv-Sign
# Shuffle-Big

# %%
mousewise.cdfplot(pwdAllH5_2, dfSummary)

# %% [markdown]
# # Mouse-average

# %%
mousewise.barplot_avg(dataDB, pwdH5data, dfSummary, 'intervName', intervNames)

# %%
mousewise.barplot_avg(dataDB, pwdH5data, dfSummary, 'trialType', trialTypes)

# %% [markdown]
# # Singlets

# %%
mousewise.plot_top_singlets(dataDB, pwdH5data, dfSummary)
# Out:
# ('bn_session', 'PRE', 'PR2', 'expert', 'None')
# ('bn_session', 'PRE', 'PR2', 'expert', 'iGO')
# ('bn_session', 'PRE', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'PRE', 'PR2', 'naive', 'None')
# ('bn_session', 'PRE', 'PR2', 'naive', 'iGO')
# ('bn_session', 'PRE', 'PR2', 'naive', 'iNOGO')
# ('bn_session', 'REW', 'PR2', 'expert', 'None')
# ('bn_session', 'REW', 'PR2', 'expert', 'iGO')
# ('bn_session', 'REW', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'REW', 'PR2', 'naive', 'None')
# ('bn_session', 'REW', 'PR2', 'naive', 'iGO')
# ('bn_session', 'REW', 'PR2', 'naive', 'iNOGO')
# ('bn_session', 'TEX', 'PR2', 'expert', 'None')
# ('bn_session', 'TEX', 'PR2', 'expert', 'iGO')
# ('bn_session', 'TEX', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'TEX', 'PR2', 'naive', 'None')
# ('bn_session', 'TEX', 'PR2', 'naive', 'iGO')
# ('bn_session', 'TEX', 'PR2', 'naive', 'iNOGO')
# ('bn_trial', 'REW', 'PR2', 'expert', 'None')
# ('bn_trial', 'REW', 'PR2', 'expert', 'iGO')
# ...

# %%
dfTop1Dmean = mousewise.plot_top_singlets_bymouse_outer2D(dataDB, pwdH5data, dfSummary, 'syn',
                                                          func=np.nanmean, dropna=True, magThr=0.02)
# Out:
# ('bn_session', 'PRE', 'PR2', 'expert', 'None')
# ('bn_session', 'PRE', 'PR2', 'expert', 'iGO')
# ('bn_session', 'PRE', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'PRE', 'PR2', 'naive', 'None')
# ('bn_session', 'PRE', 'PR2', 'naive', 'iGO')
# ('bn_session', 'PRE', 'PR2', 'naive', 'iNOGO')
# ('bn_session', 'REW', 'PR2', 'expert', 'None')
# ('bn_session', 'REW', 'PR2', 'expert', 'iGO')
# ('bn_session', 'REW', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'REW', 'PR2', 'naive', 'None')
# ('bn_session', 'REW', 'PR2', 'naive', 'iGO')
# ('bn_session', 'REW', 'PR2', 'naive', 'iNOGO')
# ('bn_session', 'TEX', 'PR2', 'expert', 'None')
# ('bn_session', 'TEX', 'PR2', 'expert', 'iGO')
# ('bn_session', 'TEX', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'TEX', 'PR2', 'naive', 'None')
# ('bn_session', 'TEX', 'PR2', 'naive', 'iGO')
# ('bn_session', 'TEX', 'PR2', 'naive', 'iNOGO')
# ('bn_trial', 'REW', 'PR2', 'expert', 'None')
# ('bn_trial', 'REW', 'PR2', 'expert', 'iGO')
# ...

# %%
dfTop1Dmax = mousewise.plot_top_singlets_bymouse_outer2D(dataDB, pwdH5data, dfSummary, 'syn',
                                                          func=np.nanmax, dropna=True, magThr=0.02)
# Out:
# ('bn_session', 'PRE', 'PR2', 'expert', 'None')
# ('bn_session', 'PRE', 'PR2', 'expert', 'iGO')
# ('bn_session', 'PRE', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'PRE', 'PR2', 'naive', 'None')
# ('bn_session', 'PRE', 'PR2', 'naive', 'iGO')
# ('bn_session', 'PRE', 'PR2', 'naive', 'iNOGO')
# ('bn_session', 'REW', 'PR2', 'expert', 'None')
# ('bn_session', 'REW', 'PR2', 'expert', 'iGO')
# ('bn_session', 'REW', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'REW', 'PR2', 'naive', 'None')
# ('bn_session', 'REW', 'PR2', 'naive', 'iGO')
# ('bn_session', 'REW', 'PR2', 'naive', 'iNOGO')
# ('bn_session', 'TEX', 'PR2', 'expert', 'None')
# ('bn_session', 'TEX', 'PR2', 'expert', 'iGO')
# ('bn_session', 'TEX', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'TEX', 'PR2', 'naive', 'None')
# ('bn_session', 'TEX', 'PR2', 'naive', 'iGO')
# ('bn_session', 'TEX', 'PR2', 'naive', 'iNOGO')
# ('bn_trial', 'REW', 'PR2', 'expert', 'None')
# ('bn_trial', 'REW', 'PR2', 'expert', 'iGO')
# ...

# %%
fig, ax = plt.subplots(ncols=2, figsize=(20, 10), tight_layout=True)

for i, datatype in enumerate(['bn_trial', 'bn_session']):
    dfQuery = pd_query(dfTop1Dmean, {'datatype': datatype})
    dfQuery = dfQuery[dfQuery['trialType'] != 'None']
    ax[i].set_title(datatype)
    plot_df_2D_outer_product(ax[i], dfQuery, ['label'], ['datatype', 'mousename', 'intervName', 'trialType', 'performance'],
                             'syn', vmin=0, orderDict={'intervName': ['PRE', 'TEX', 'REW']}, 
                             dropEmpty=True)
    
#plt.savefig('pid_tex_big_outer2d.svg')
plt.show()

# %%
fig, ax = plt.subplots(ncols=2, figsize=(20, 10), tight_layout=True)

for i, datatype in enumerate(['bn_trial', 'bn_session']):
    dfQuery = pd_query(dfTop1Dmax, {'datatype': datatype})
    dfQuery = dfQuery[dfQuery['trialType'] != 'None']
    ax[i].set_title(datatype)
    plot_df_2D_outer_product(ax[i], dfQuery, ['label'], ['datatype', 'mousename', 'intervName', 'trialType', 'performance'],
                             'syn', vmin=0, orderDict={'intervName': ['PRE', 'TEX', 'REW']}, 
                             dropEmpty=True)
    
# plt.savefig('pid_tex_big_outer2d.svg')
plt.show()

# %% [markdown]
# # Triplets

# %%
mousewise.plot_top_triplets(dataDB, pwdH5data, dfSummary, nTop=20)#, dropChannels=['BC'])
# Out:
# ('bn_session', 'PRE', 'PR2', 'expert', 'None')
# ('bn_session', 'PRE', 'PR2', 'expert', 'iGO')
# ('bn_session', 'PRE', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'PRE', 'PR2', 'naive', 'None')
# ('bn_session', 'PRE', 'PR2', 'naive', 'iGO')
# ('bn_session', 'PRE', 'PR2', 'naive', 'iNOGO')
# ('bn_session', 'REW', 'PR2', 'expert', 'None')
# ('bn_session', 'REW', 'PR2', 'expert', 'iGO')
# ('bn_session', 'REW', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'REW', 'PR2', 'naive', 'None')
# ('bn_session', 'REW', 'PR2', 'naive', 'iGO')
# ('bn_session', 'REW', 'PR2', 'naive', 'iNOGO')
# ('bn_session', 'TEX', 'PR2', 'expert', 'None')
# ('bn_session', 'TEX', 'PR2', 'expert', 'iGO')
# ('bn_session', 'TEX', 'PR2', 'expert', 'iNOGO')
# ('bn_session', 'TEX', 'PR2', 'naive', 'None')
# ('bn_session', 'TEX', 'PR2', 'naive', 'iGO')
# ('bn_session', 'TEX', 'PR2', 'naive', 'iNOGO')
# ('bn_trial', 'REW', 'PR2', 'expert', 'None')
# ('bn_trial', 'REW', 'PR2', 'expert', 'iGO')
# ...

# %%
dictDictSelectedTriplets = {
#     'max': mousewise.plot_filter_top_triplets_bymouse(dataDB, pwdH5data, dfSummary, filterRule='metric_max',
#                                                       nTop=30, thrBig=0.01, dropWeak=True),
#     'mean': mousewise.plot_filter_top_triplets_bymouse(dataDB, pwdH5data, dfSummary, filterRule='metric_mean',
#                                                       nTop=30, thrBig=0.01, dropWeak=True),
#     'count': mousewise.plot_filter_top_triplets_bymouse(dataDB, pwdH5data, dfSummary, filterRule='metric_count',
#                                                         nTop=30, thrBig=0.05, dropWeak=True),
#     'consistent': mousewise.plot_filter_top_triplets_bymouse(dataDB, pwdH5data, dfSummary, filterRule='consistent',
#                                                              nTop=50, thrBig=0.01, nConsistent=4, dropWeak=True)
    'mouse_consistent': mousewise.plot_filter_top_triplets_bymouse(dataDB, pwdH5data, dfSummary,
                                                                   filterRule='mouse_consistent', nTop=30,
                                                                   thrBig=0.02, dropWeak=True)
}
# Out:
# bn_session
# -- [4.00702906 4.00545719 4.00514139 4.005097   4.00507065 4.00504871
#  4.00498849 4.00480748 4.00479381 4.00470192 4.00469397 4.00469114
#  4.00462435 4.00452971 4.00447389 4.00443117 4.00435787 4.00427718
#  4.00423868 4.00422679 4.00409094 4.00401226 4.00396155 4.00394046
#  4.00390914 4.00386548 4.00386072 4.00379144 4.00377925 4.00377314]
# nTriplets passing mouse_consistent 30
# bn_trial
# -- [3.00378478 3.00368655 3.00353759 3.00343961 3.00338758 3.00333953
#  3.00333107 3.00332835 3.00305697 3.00300785 3.0028746  3.00286807
#  3.00286364 3.00284992 3.0028431  3.00283405 3.00281893 3.00276805
#  3.00273871 3.00270789 3.00266725 3.00264239 3.00251801 3.00250802
#  3.00248926 3.00245327 3.00243022 3.00242817 3.00240241 3.00237653]
# nTriplets passing mouse_consistent 30

# %%
for filterRule, dfSelectedTriplets in dictDictSelectedTriplets.items():
    print(filterRule)
    
    vmax = None if filterRule in ['max', 'mouse_consistent'] else 0.3

    fig, ax = plt.subplots(ncols=2, figsize=(20, 10), tight_layout=True)

    for i, datatype in enumerate(['bn_trial', 'bn_session']):
        ax[i].set_title(datatype)
        plot_df_2D_outer_product(ax[i], dfSelectedTriplets[datatype], ['label'],
                                 ['mousename', 'intervName', 'trialType', 'performance'],
                                 'syn', vmin=0, vmax=vmax, orderDict={'intervName': ['PRE', 'TEX', 'REW']}, 
                                 dropEmpty=True)

    plt.savefig('pr2_tex_big_triplets_outer2d'+filterRule+'.svg')
    plt.show()
# Out:
# mouse_consistent

# %%
pid_joint.plot_triplets(dataDB, pwdAllH5_2, dfSummary, nTop=20)

# %%
pid_joint.plot_singlets(dataDB, pwdAllH5_2, dfSummary, nTop=20)

# %%
# TODO: Unique: Sweep over pairs of (S1,T) vs S2, as opposed to (S1,S2) vs T
pid_joint.plot_2D_avg(dataDB, pwdAllH5_2, dfSummary, dropChannels=None, avgAxis=1)

# %%
pid_joint.plot_2D_bytarget(dataDB, pwdAllH5_2, dfSummary, 'Rt', dropChannels=None)

# %%
pid_joint.plot_2D_bytarget_synergy_cluster(dataDB, pwdAllH5_2, dfSummary, 'VPL',
                                           dropChannels=[21], clusterParam=2, dropWeakChannelThr=0.1)

# %%
pid_joint.plot_unique_top_pairs(dataDB, pwdAllH5_2, dfSummary, nTop=20, dropChannels=None)

# %% [markdown]
# # Consistency
#
# ## 1. Across Mice

# %%
pid_joint.plot_consistency_bymouse(pwdAllH5_2, dfSummary, dropChannels=[21], performance='naive',
                                   kind='fisher', limits=[0, 1])
pid_joint.plot_consistency_bymouse(pwdAllH5_2, dfSummary, dropChannels=[21], performance='expert',
                                   kind='fisher', limits=[0, 1])

# %%
pid_joint.plot_consistency_byphase(pwdAllH5_2, dfSummary, dropChannels=[21], performance='naive',
                                   kind='fisher', limits=[0, 1], datatype='bn_trial')
pid_joint.plot_consistency_byphase(pwdAllH5_2, dfSummary, dropChannels=[21], performance='expert',
                                   kind='fisher', limits=[0, 1], datatype='bn_trial')
pid_joint.plot_consistency_byphase(pwdAllH5_2, dfSummary, dropChannels=[21], performance='naive',
                                   kind='fisher', limits=[0, 1], datatype='bn_session')
pid_joint.plot_consistency_byphase(pwdAllH5_2, dfSummary, dropChannels=[21], performance='expert',
                                   kind='fisher', limits=[0, 1], datatype='bn_session')

# %%
pid_joint.plot_consistency_bytrialtype(pwdAllH5_2, dfSummary, dropChannels=[21], performance='naive', datatype='bn_trial',
                                 trialTypes=['iGO', 'iNOGO'], kind='fisher', fisherThr=0.1, limits=[0, 1])
pid_joint.plot_consistency_bytrialtype(pwdAllH5_2, dfSummary, dropChannels=[21], performance='expert', datatype='bn_trial',
                                 trialTypes=['iGO', 'iNOGO'], kind='fisher', fisherThr=0.1, limits=[0, 1])
pid_joint.plot_consistency_bytrialtype(pwdAllH5_2, dfSummary, dropChannels=[21], performance='naive', datatype='bn_session',
                                 trialTypes=['iGO', 'iNOGO'], kind='fisher', fisherThr=0.1, limits=[0, 1])
pid_joint.plot_consistency_bytrialtype(pwdAllH5_2, dfSummary, dropChannels=[21], performance='expert', datatype='bn_session',
                                 trialTypes=['iGO', 'iNOGO'], kind='fisher', fisherThr=0.1, limits=[0, 1])

# %% [markdown]
# ## Sanity check if PID matches pre-computed

# %%
for datatype in ['bn_session', 'bn_trial']:
    for intervName in intervNames:
        for trialType in [None, 'iGO', 'iNOGO']:
            for mousename in ['mvg_4']: #sorted(dataDB.mice):
                print(datatype, intervName, trialType, mousename)
                
                channelNames = dataDB.get_channel_labels(mousename)
                dataLst = dataDB.get_neuro_data({'mousename': mousename}, datatype=datatype,
                                                trialType=trialType,
                                                zscoreDim='rs', intervName=intervName)

                display(pid.pid(dataLst, mc, channelNames, ['S1_bf', 'VPL'], ['LGP'], nPerm=100, nBin=4))
                break
            break
        break
    break
